# %% [markdown]
# <a href="https://colab.research.google.com/github/SurajGavade01/Suraj_31_DEC_2025_Bank/blob/main/Seaborn_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Total bill vs Tip")
plt.show()

# %%
sns.lineplot(x="total_bill", y="tip", data=tips)
plt.title("Total bill vs Tip(Line Plot)")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Total bill by Day")
plt.show()

# %%
sns.barplot(x="time", y="total_bill", data=tips)
plt.title("Total bill by Day")
plt.show()

# %%
sns.barplot(x="sex", y="total_bill", data=tips)
plt.title("Total bill by Day")
plt.show()

# %%
sns.barplot(x="smoker", y="total_bill", data=tips)
plt.title("Total bill by Day")
plt.show()

# %%
tips[tips['smoker'] == 'Yes']["sex"].value_counts()
# Out:
# sex
# Male      60
# Female    33
# Name: count, dtype: int64

# %%
sns.histplot(tips["total_bill"], kde = True)
plt.title("Distribution of Total Bill")
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("Total bill by Day (Box Plot)")
plt.show()

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
sns.pairplot(df, hue='species')
plt.show()
