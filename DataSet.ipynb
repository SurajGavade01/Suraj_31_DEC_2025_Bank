# %% [markdown]
# <a href="https://colab.research.google.com/github/SurajGavade01/Suraj_31_DEC_2025_Bank/blob/main/DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/car_price_dataset.csv')
df.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %% [markdown]
# 1.what is the average. price of all the cars in the datasets?

# %%
avg = df['Price'].mean()
print(f'the average price of all the cars in the dataset {avg}')
# Out:
# the averge price of all the cars in the dataset 8852.9644

# %% [markdown]
# 2. which car brand has the highest averge price ?

# %%
s = df.groupby('Brand')['Price'].mean().idxmax()

print(f'the car brand with the highest averge price is {s}')
# Out:
# the car brand with the highest averge price is Chevrolet

# %% [markdown]
# #3. What is the most common fuel type in the dataset?
# #4.How many cars have a mileage greater than 200,000?
# #5.WHat is the distribution of cars by transmission type?
# #6.Which car model has the highest price?
# #7.WHat is the average price of cars by fuel type?
# #8.How many cars are from the year 2020 or later?
# #9.what is the average engine size for each brand?
# #10.Which car has the lowest mileage?

# %% [markdown]
# #3. What is the most common fuel type in the dataset?

# %%
s = df['Fuel_Type'].value_counts().idxmax()
print(f'The most common fuel type in the dataset is: {s}')
# Out:
# The most common fuel type in the dataset is: Electric

# %% [markdown]
# 4.How many cars have a mileage greater than 200,000?

# %%
len(df[df['Mileage']>200000])
# Out:
# 3290

# %% [markdown]
# 6.Which car model has the highest price?

# %%
df.loc[df['Price'].idxmax(), ['Model', 'Price']].tolist()
# Out:
# ['Corolla', np.int64(18301)]

# %% [markdown]
# #7.WHat is the average price of cars by fuel type?

# %%
df.groupby('Fuel_Type')['Price'].mean()
# Out:
# Fuel_Type
# Diesel       8117.336385
# Electric    10032.220190
# Hybrid       9113.030167
# Petrol       8070.561826
# Name: Price, dtype: float64

# %% [markdown]
# How many cars are from the year 2020 or later?

# %%
len(df[df['Year'] >= 2020])
# Out:
# 1651

# %% [markdown]
# what is the average engine size for each brand?

# %%
df.groupby('Brand')['Engine_Size'].mean()
# Out:
# Brand
# Audi          3.032948
# BMW           2.976877
# Chevrolet     2.993719
# Ford          3.044275
# Honda         2.925966
# Hyundai       2.936683
# Kia           3.053791
# Mercedes      3.069745
# Toyota        2.961443
# Volkswagen    3.011078
# Name: Engine_Size, dtype: float64

# %%
df.groupby('Brand')['Engine_Size'].mean().idxmax()
# Out:
# 'Mercedes'

# %% [markdown]
# 10.Which car has the lowest mileage?

# %%
df.groupby('Brand')['Mileage'].min().idxmin()
# Out:
# 'Ford'

# %% [markdown]
# 11. What is the correlation between mileage and price?

# %% [markdown]
# 12.How many cars have more than 2 owners?

# %%
len(df[df['Owner_Count'] > 2])
# Out:
# 5944

# %% [markdown]
# 13.13. What is the average price of cars by year?

# %%
df.groupby('Year')['Price'].mean()
# Out:
# Year
# 2000     5393.735369
# 2001     5904.064039
# 2002     5956.751082
# 2003     6225.834646
# 2004     6330.725888
# 2005     6943.037123
# 2006     7249.961446
# 2007     7632.513953
# 2008     7728.418848
# 2009     8083.917293
# 2010     8503.419954
# 2011     8622.855234
# 2012     9011.446224
# 2013     9114.208531
# 2014     9587.455635
# 2015     9896.774648
# 2016    10177.600000
# 2017    10343.757506
# 2018    10939.192941
# 2019    11132.722090
# 2020    11495.284337
# 2021    11637.813299
# 2022    12067.690176
# 2023    12169.470982
# Name: Price, dtype: float64

# %%
df.groupby('Year')['Price'].mean().idxmax()
# Out:
# np.int64(2023)

# %% [markdown]
# 14.Which car has the highest number of doors?

# %%
df.groupby('Brand')['Doors'].max()
# Out:
# Brand
# Audi          5
# BMW           5
# Chevrolet     5
# Ford          5
# Honda         5
# Hyundai       5
# Kia           5
# Mercedes      5
# Toyota        5
# Volkswagen    5
# Name: Doors, dtype: int64

# %%
df.groupby('Brand')['Doors'].max().idxmax()
# Out:
# 'Audi'

# %% [markdown]
# 15. What is the average mileage for each fuel type?

# %%
df.groupby('Fuel_Type')['Mileage'].mean()
# Out:
# Fuel_Type
# Diesel      150261.533041
# Electric    151059.307429
# Hybrid      145577.587036
# Petrol      149917.694606
# Name: Mileage, dtype: float64

# %% [markdown]
# 16.How many cars are from the brand 'Toyota'?

# %%
len(df[df['Brand'] == 'Toyota'])
# Out:
# 970

# %% [markdown]
# 17.What is the average price of cars with automatic transmission?
